# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3], [4, pd.NA ,6], [7,8,9]], columns=['A', 'B', 'C'], index=['X', 2, 'B'])

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['X', 2, 'B']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to B
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       2 non-null      object
#  2   C       3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    C
# count  3.0  3.0
# mean   4.0  6.0
# std    3.0  3.0
# min    1.0  3.0
# 25%    2.5  4.5
# 50%    4.0  6.0
# 75%    5.5  7.5
# max    7.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    2
# C    3
# dtype: int64

# %%
df['A'].nunique()
# Out:
# 3

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# ## Loading in DataFrame from files

# %%
coffee = pd.read_csv('./warmup-data/coffee.csv')

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        10.0
# Monday        Monday       Latte        10.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0

# %%
results = pd.read_parquet('./data/results.parquet')

# %%
results.head(3)
# Out:
#      year    type discipline                   event                     as  \
# 0  1912.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis  Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc            team  place   tied medal
# 0           1  FRA            None   17.0   True  None
# 1           1  FRA  Jean Montariol    NaN  False  None
# 2           1  FRA            None   32.0   True  None

# %%
olympics_data = pd.read_excel('./data/olympics-data.xlsx')

# %%
olympics_data.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(5)
# Out:
#                Day Coffee Type  Units Sold
# Day
# Sunday      Sunday    Espresso        45.0
# Tuesday    Tuesday       Latte        20.0
# Thursday  Thursday       Latte        30.0
# Friday      Friday    Espresso        45.0
# Thursday  Thursday    Espresso        40.0

# %% [markdown]
# ## Accessing Data With Pandas

# %%
coffee.index = coffee['Day']

# %%
coffee.head(5)
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        10.0
# Monday        Monday       Latte        10.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0

# %%
coffee.loc['Monday']
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso        10.0
# Monday  Monday       Latte        10.0

# %%
# coffee.loc[#Rows, #Columns]
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffee.loc[:]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[2:5, ['Coffee Type', 'Units Sold']]
# Out:
#   Coffee Type  Units Sold
# 2    Espresso          30
# 3       Latte          20
# 4    Espresso          35
# 5       Latte          25

# %%
coffee.iloc[:,[0, 2]] # iloc only using index values
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.loc[1:'Monday', 'Units Sold'] = 100

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso       100.0
# Monday        Monday       Latte       100.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0
# Wednesday  Wednesday       Latte        25.0
# Thursday    Thursday    Espresso        40.0
# Thursday    Thursday       Latte        30.0
# Friday        Friday    Espresso        45.0
# Friday        Friday       Latte        35.0
# Saturday    Saturday    Espresso        45.0
# Saturday    Saturday       Latte        35.0
# Sunday        Sunday    Espresso        45.0
# Sunday        Sunday       Latte        35.0
# 1                NaN         NaN        10.0

# %%
coffee.at['Tuesday', 'Units Sold'] # rows, columns
# coffee.iat[1, 2] # index, index
# Out:
# Day
# Tuesday    30.0
# Tuesday    20.0
# Name: Units Sold, dtype: float64

# %%
coffee.reset_index(drop=True, inplace=True)

# %%
coffee['Day']
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# 14          NaN
# Name: Day, dtype: object

# %%
coffee.sort_values(['Units Sold', 'Coffee Type'], ascending=[0, 1]) # asceding = false, true
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso       100.0
# 1      Monday       Latte       100.0
# 8      Friday    Espresso        45.0
# 10   Saturday    Espresso        45.0
# 12     Sunday    Espresso        45.0
# 6    Thursday    Espresso        40.0
# 4   Wednesday    Espresso        35.0
# 9      Friday       Latte        35.0
# 11   Saturday       Latte        35.0
# 13     Sunday       Latte        35.0
# 2     Tuesday    Espresso        30.0
# 7    Thursday       Latte        30.0
# 5   Wednesday       Latte        25.0
# 3     Tuesday       Latte        20.0
# 14        NaN         NaN        10.0

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row['Units Sold'])
    print("\n\n\n")
# Out:
# 0
# 25
#
#
#
#
# 1
# 15
#
#
#
#
# 2
# 30
#
#
#
#
# 3
# 20
#
#
#
#
# 4
# 35
#
#
#
#
# 5
# 25
#
#
#
#
# 6
# 40
#
#
#
#
# 7
# 30
#
#
#
#
# 8
# 45
#
#
#
#
# 9
# 35
#
#
#
#
# 10
# 45
#
#
#
#
# 11
# 35
#
#
#
#
# 12
# 45
#
#
#
#
# 13
# 35

# %% [markdown]
# ## Filtering Data

# %%
bios = pd.read_csv('./data/bios.csv')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios['height_cm'] > 215, ['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[bios['height_cm'] > 220][['name', 'height_cm', 'weight_kg']]
# Out:
#                    name  height_cm  weight_kg
# 5673     Gunther Behnke      221.0      114.0
# 5781     Tommy Burleson      223.0      102.0
# 6978    Arvydas Sabonis      223.0      122.0
# 89070          Yao Ming      226.0      141.0
# 89075    Roberto Dueñas      221.0      137.0
# 120266     Zhang Zhaoxu      221.0      110.0

# %%
bios[(bios['height_cm'] > 218) & (bios['born_country'] == 'USA')]
# Out:
#       athlete_id            name   born_date  born_city     born_region  \
# 5781        5804  Tommy Burleson  1952-02-24  Crossnore  North Carolina
#
#      born_country            NOC  height_cm  weight_kg died_date
# 5781          USA  United States      223.0      102.0       NaN

# %%
bios[bios['born_country'].isin(['USA', 'FRA', 'GBR']) & (bios['name'].str.startswith('K'))]
# Out:
#         athlete_id             name   born_date   born_city  born_region  \
# 58              59     Kitty McKane  1896-05-07   Bayswater      England
# 60              61     Kelly Morgan  1975-05-22  Pontypridd        Wales
# 546            548  Katherine Mudge  1881-08-16    Llanbedr        Wales
# 3210          3222      Kris Benson  1974-11-07      Duluth    Minnesota
# 3220          3232    Kip Harkrider  1975-09-16    Carthage        Texas
# ...            ...              ...         ...         ...          ...
# 145386      149109  Kaitlin Hawayek  1996-11-04     Buffalo     New York
# 145400      149123   Kenny Agostino  1992-04-30  Morristown   New Jersey
# 145436      149159     Kelly Curtis  1989-01-25   Princeton   New Jersey
# 145439      149162       Kimi Goetz  1994-08-13  Flemington   New Jersey
# 145445      149168   Kristen Santos  1994-11-02   Fairfield  Connecticut
#
#        born_country            NOC  height_cm  weight_kg   died_date
# ...

# %%
bios.query('born_country == "USA" and height_cm > 210')
# Out:
#         athlete_id                name   born_date         born_city  \
# 5681          5704        Walt Bellamy  1937-07-24          New Bern
# 5781          5804      Tommy Burleson  1952-02-24         Crossnore
# 5894          5919          Mel Counts  1941-10-16          Coos Bay
# 6106          6133     Marc Freiberger  1928-11-27          Amarillo
# 6281          6309      Darrall Imhoff  1938-10-11       San Gabriel
# 6379          6410          Joe Kleine  1962-01-04  Colorado Springs
# 6393          6424          Jon Koncak  1963-05-17      Cedar Rapids
# 6442          6473  Christian Laettner  1969-08-17            Angola
# 6615          6648        Tom McMillen  1952-05-26         Mansfield
# 6722          6755    Shaquille O'Neal  1972-03-06            Newark
# 6937          6972      David Robinson  1965-08-06          Key West
# 7012          7048     Daniel Santiago  1976-06-24    Tarpon Springs
# 112319      113575         Chris Kaman  1982-04-28           Wyoming
# ...

# %% [markdown]
# ## Adding / Removing Columns

# %%
coffee_new = coffee.copy()
# coffee['price'] = 4.99
coffee_new['price'] = 4.99

# %%
import numpy as np
coffee_new['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)

# %%
# coffee.drop(columns=['price'], inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price  revenue
# 0     Monday    Espresso          25       3.99    99.75
# 1     Monday       Latte          15       5.99    89.85
# 2    Tuesday    Espresso          30       3.99   119.70
# 3    Tuesday       Latte          20       5.99   119.80
# 4  Wednesday    Espresso          35       3.99   139.65

# %%
coffee = coffee.rename(columns={ 'new_price': 'price'})

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new.query('first_name == "Bill"')
# Out:
#         athlete_id           name   born_date     born_city  \
# 1156          1163    Bill Dunlop  1963-11-19      Montréal
# 3361          3373     Bill Child  1884-08-07      Swaffham
# 3372          3384      Bill Dees  1874-09-28     Liverpool
# 3423          3435    Bill Knight  1951-07-26           NaN
# 3476          3488  Bill Robinson  1936-02-20           NaN
# ...            ...            ...         ...           ...
# 101529      102419    Bill Tuttle  1882-02-21       Chicago
# 101582      102483     Bill Stowe  1940-03-23      Oak Park
# 101640      102558    Bill Havens  1919-01-29    Washington
# 121254      123228     Bill Lucas  1987-09-13        Exeter
# 145499      149814  Bill Phillips  1913-07-15  Dulwich Hill
#
#                  born_region born_country            NOC  height_cm  \
# 1156                  Québec          CAN         Canada      168.0
# 3361                 England          GBR  Great Britain        NaN
# ...

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'], errors='coerce', format='%Y-%m-%d')

# %%
bios_new['born_year'] = bios_new['born_datetime'].dt.year

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year
# 0  1960-10-02  Jean-François    1886-12-12     1886.0
# 1         NaN         Arnaud    1969-04-01     1969.0
# ...

# %%
bios_new.to_csv('./data/bios_new.csv', index=False)

# %%
bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x < 185 else 'Tall') )

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 or row['weight_kg'] <=80:
        return 'Middleweight'
    else:
        return 'Heavyweight'
bios['category'] = bios.apply(categorize_athlete, axis=1)

# %% [markdown]
# ## Merging & Concatenating Data

# %%
nocs = pd.read_csv('./data/noc_regions.csv')

# %%
bios_new2 = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left')

# %%
bios_new2.rename(columns={'region': 'born_country_full'}, inplace=True)

# %%
bios_new2[bios_new2['NOC_x'] != bios_new2['born_country_full']][['name', 'NOC_x', 'born_country_full']]
# Out:
#                        name    NOC_x born_country_full
# 4              Albert Canet   France                UK
# 12                J. Defert   France               NaN
# 13           Étienne Durand   France               NaN
# 16               Guy Forget   France           Morocco
# 27       Guy, Baron Lejeune   France               NaN
# ...                     ...      ...               ...
# 145491        Matthew Wepke  Jamaica               NaN
# 145493   Landysh Falyakhova      ROC            Russia
# 145495    Polina Luchnikova      ROC            Russia
# 145496  Valeriya Merkusheva      ROC            Russia
# 145497      Yuliya Smirnova      ROC            Russia
#
# [73210 rows x 3 columns]

# %%
usa = bios[bios['born_country'] == 'USA'].copy()
gbr = bios[bios['born_country'] == 'GBR'].copy()

# %%
new_df = pd.concat([usa, gbr])

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
combined_df = pd.merge(results, bios, on='athlete_id', how='left')

# %%
combined_df.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal  \
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None
#
#                     name   born_date born_city born_region born_country  \
# 0  Jean-François Blanchy  1886-12-12  Bordeaux     Gironde          FRA
# ...

# %% [markdown]
# ## Handling Null Values

# %%
coffee.loc[[0,1], 'Units Sold'] = 15.00

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# price          0
# revenue        0
# dtype: int64

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso   15.990000   3.99    99.75
# 1      Monday       Latte   15.990000   5.99    89.85
# 2     Tuesday    Espresso   33.498333   3.99   119.70
# 3     Tuesday       Latte   33.498333   5.99   119.80
# 4   Wednesday    Espresso   35.000000   3.99   139.65
# 5   Wednesday       Latte   25.000000   5.99   149.75
# 6    Thursday    Espresso   40.000000   3.99   159.60
# 7    Thursday       Latte   30.000000   5.99   179.70
# 8      Friday    Espresso   45.000000   3.99   179.55
# 9      Friday       Latte   35.000000   5.99   209.65
# 10   Saturday    Espresso   45.000000   3.99   179.55
# 11   Saturday       Latte   35.000000   5.99   209.65
# 12     Sunday    Espresso   45.000000   3.99   179.55
# 13     Sunday       Latte   35.000000   5.99   209.65

# %%
coffee.loc[[5,4], 'Units Sold'] = np.nan

# %%
# coffee['Units Sold'] = coffee['Units Sold'].interpolate()

# %%
coffee.dropna(subset=['Units Sold'], inplace=True)

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 4  Wednesday    Espresso         NaN   3.99   139.65
# 5  Wednesday       Latte         NaN   5.99   149.75

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso        15.0   3.99    99.75
# 1     Monday       Latte        15.0   5.99    89.85
# 6   Thursday    Espresso        40.0   3.99   159.60
# 7   Thursday       Latte        30.0   5.99   179.70
# 8     Friday    Espresso        45.0   3.99   179.55
# 9     Friday       Latte        35.0   5.99   209.65
# 10  Saturday    Espresso        45.0   3.99   179.55
# 11  Saturday       Latte        35.0   5.99   209.65
# 12    Sunday    Espresso        45.0   3.99   179.55
# 13    Sunday       Latte        35.0   5.99   209.65
